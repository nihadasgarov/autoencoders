# %%
pip install mediapipe

# %%
#First run this cell in order to get frames of video.
# it saves frames into folder names like video name+opencv
#after running first cell, please run second cell to see result


from datetime import timedelta
import cv2
import numpy as np
import os

# i.e if video of duration 30 seconds, saves 10 frame per second = 300 frames saved in total
SAVING_FRAMES_PER_SECOND = 10

def format_timedelta(td):
    """Utility function to format timedelta objects in a cool way (e.g 00:00:20.05)
    omitting microseconds and retaining milliseconds"""
    result = str(td)
    try:
        result, ms = result.split(".")
    except ValueError:
        return result + ".00".replace(":", "-")
    ms = int(ms)
    ms = round(ms / 1e4)
    return f"{result}.{ms:02}".replace(":", "-")


def get_saving_frames_durations(cap, saving_fps):
    """A function that returns the list of durations where to save the frames"""
    s = []
    # get the clip duration by dividing number of frames by the number of frames per second
    clip_duration = cap.get(cv2.CAP_PROP_FRAME_COUNT) / cap.get(cv2.CAP_PROP_FPS)
    # use np.arange() to make floating-point steps
    for i in np.arange(0, clip_duration, 1 / saving_fps):
        s.append(i)
    return s


def main(video_file,filename):
    # make a folder by the name of the video file
    if not os.path.isdir(filename):
        os.mkdir(filename)
    # read the video file
    cap = cv2.VideoCapture(video_file)
    # get the FPS of the video
    fps = cap.get(cv2.CAP_PROP_FPS)
    # if the SAVING_FRAMES_PER_SECOND is above video FPS, then set it to FPS (as maximum)
    saving_frames_per_second = min(fps, SAVING_FRAMES_PER_SECOND)
    # get the list of duration spots to save
    saving_frames_durations = get_saving_frames_durations(cap, saving_frames_per_second)
    # start the loop
    count = 0
    while True:
        is_read, frame = cap.read()
        if not is_read:
            # break out of the loop if there are no frames to read
            break
        # get the duration by dividing the frame count by the FPS
        frame_duration = count / fps
        try:
            # get the earliest duration to save
            closest_duration = saving_frames_durations[0]
        except IndexError:
            # the list is empty, all duration frames were saved
            break
        if frame_duration >= closest_duration:
            # if closest duration is less than or equals the frame duration,
            # then save the frame
            frame_duration_formatted = format_timedelta(timedelta(seconds=frame_duration))
            cv2.imwrite(os.path.join(filename, f"frame{frame_duration_formatted}.jpg"), frame)
            # drop the duration spot from the list, since this duration spot is already saved
            try:
                saving_frames_durations.pop(0)
            except IndexError:
                pass
        # increment the frame count
        count += 1
        



if __name__ == "__main__":
    import sys
    #write your file path here
    video_file = "/content/2022-10-21 19-22-27.mkv"
    filename, _ = os.path.splitext(video_file)
    filename += "-opencv"
    main(video_file,filename)

# %%
#run this cell to see if picture contains hand or not. It can contain both hands
from google.colab.patches import cv2_imshow
import mediapipe as mp
from os import listdir
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_hands = mp.solutions.hands
mp_model = mp_hands.Hands(
    static_image_mode=True, # only static images
    max_num_hands=2, # max 2 hands detection
    min_detection_confidence=0.5) # detection confidence
    


list1=[]
folder_dir = filename
for image in os.listdir(folder_dir):
  if (image.endswith(".png") or image.endswith(".jpg")\
        or image.endswith(".jpeg")):
    path=image
    if os.path.exists(folder_dir+"/"+image):
      image = cv2.imread(folder_dir+"/"+image)
    # now we flip image and convert to rgb image and input to model
      image = cv2.flip(image, 1)
    
      results = mp_model.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
      print(path,results.multi_handedness,sep="      ")
    else:
        print("Empty image")
    

#none means no hand
# "label": Right -> right hand
#"label": Left-> left hand
# Out:
# frame0-00-13.13.jpg      None
# frame0:00:00.00.jpg      None
# frame0-00-02.43.jpg      [classification {
#   index: 1
#   score: 0.9680936932563782
#   label: "Right"
# }
# ]
# frame0-00-10.90.jpg      [classification {
#   index: 0
#   score: 0.9811246395111084
#   label: "Left"
# }
# ]
# frame0:00:11.00.jpg      [classification {
#   index: 0
#   score: 0.9738714098930359
#   label: "Left"
# }
# ]
# frame0:00:07.00.jpg      [classification {
#   index: 1
#   score: 0.9538634419441223
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9844574928283691
#   label: "Left"
# }
# ]
# frame0-00-09.30.jpg      [classification {
#   index: 1
#   score: 0.966688334941864
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9781812429428101
#   label: "Left"
# }
# ]
# frame0-00-08.90.jpg      [classification {
#   index: 1
#   score: 0.9786240458488464
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9819427132606506
#   label: "Left"
# }
# ]
# frame0-00-10.73.jpg      [classification {
#   index: 1
#   score: 0.9784550070762634
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9718791246414185
#   label: "Left"
# }
# ]
# frame0-00-00.10.jpg      None
# frame0-00-04.70.jpg      [classification {
#   index: 0
#   score: 0.9663106799125671
#   label: "Left"
# }
# ]
# frame0-00-04.40.jpg      [classification {
#   index: 0
#   score: 0.9652989506721497
#   label: "Left"
# }
# ]
# frame0-00-07.90.jpg      [classification {
#   index: 0
#   score: 0.9728528261184692
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9781869053840637
#   label: "Right"
# }
# ]
# frame0-00-13.40.jpg      None
# frame0-00-06.20.jpg      None
# frame0-00-04.30.jpg      [classification {
#   index: 1
#   score: 0.9481488466262817
#   label: "Right"
# }
# ]
# frame0-00-07.83.jpg      [classification {
#   index: 0
#   score: 0.9733147621154785
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9794486165046692
#   label: "Right"
# }
# ]
# frame0-00-08.23.jpg      [classification {
#   index: 1
#   score: 0.9536725282669067
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9572312235832214
#   label: "Left"
# }
# ]
# frame0:00:02.00.jpg      None
# frame0-00-12.13.jpg      [classification {
#   index: 0
#   score: 0.9801296591758728
#   label: "Left"
# }
# ]
# frame0-00-06.50.jpg      None
# frame0:00:01.00.jpg      None
# frame0-00-05.33.jpg      [classification {
#   index: 1
#   score: 0.9914305210113525
#   label: "Right"
# }
# ]
# frame0-00-02.33.jpg      [classification {
#   index: 1
#   score: 0.9479900002479553
#   label: "Right"
# }
# ]
# frame0-00-06.13.jpg      None
# frame0-00-13.23.jpg      None
# frame0-00-09.50.jpg      [classification {
#   index: 1
#   score: 0.9744725227355957
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9837415814399719
#   label: "Left"
# }
# ]
# frame0-00-08.80.jpg      [classification {
#   index: 0
#   score: 0.9796452522277832
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9501634836196899
#   label: "Right"
# }
# ]
# frame0-00-07.13.jpg      [classification {
#   index: 1
#   score: 0.9792410731315613
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9643798470497131
#   label: "Left"
# }
# ]
# frame0-00-10.30.jpg      [classification {
#   index: 0
#   score: 0.978927493095398
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9771174788475037
#   label: "Right"
# }
# ]
# frame0-00-01.60.jpg      None
# frame0-00-00.40.jpg      None
# frame0-00-10.23.jpg      [classification {
#   index: 1
#   score: 0.9760913848876953
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9838462471961975
#   label: "Left"
# }
# ]
# frame0-00-09.63.jpg      [classification {
#   index: 1
#   score: 0.9870298504829407
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9809522032737732
#   label: "Left"
# }
# ]
# frame0:00:09.00.jpg      [classification {
#   index: 0
#   score: 0.9811517596244812
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9687017202377319
#   label: "Right"
# }
# ]
# frame0-00-00.80.jpg      None
# frame0-00-00.63.jpg      None
# frame0-00-09.90.jpg      [classification {
#   index: 1
#   score: 0.980270504951477
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9806817770004272
#   label: "Left"
# }
# ]
# frame0-00-11.23.jpg      [classification {
#   index: 0
#   score: 0.9826086759567261
#   label: "Left"
# }
# ]
# frame0-00-08.50.jpg      [classification {
#   index: 1
#   score: 0.897197425365448
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9682298898696899
#   label: "Left"
# }
# ]
# frame0-00-00.20.jpg      None
# frame0-00-12.63.jpg      None
# frame0-00-03.70.jpg      [classification {
#   index: 1
#   score: 0.9409235119819641
#   label: "Right"
# }
# ]
# frame0:00:10.00.jpg      [classification {
#   index: 1
#   score: 0.9852845072746277
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9784873723983765
#   label: "Left"
# }
# ]
# frame0-00-10.13.jpg      [classification {
#   index: 1
#   score: 0.9813165664672852
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9823040962219238
#   label: "Left"
# }
# ]
# frame0:00:12.00.jpg      [classification {
#   index: 0
#   score: 0.9808074235916138
#   label: "Left"
# }
# ]
# frame0-00-07.33.jpg      [classification {
#   index: 1
#   score: 0.9725167155265808
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9770880341529846
#   label: "Left"
# }
# ]
# frame0-00-04.83.jpg      [classification {
#   index: 0
#   score: 0.9671334028244019
#   label: "Left"
# }
# ]
# frame0-00-07.70.jpg      [classification {
#   index: 0
#   score: 0.9758372902870178
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.975138247013092
#   label: "Right"
# }
# ]
# frame0-00-06.70.jpg      [classification {
#   index: 1
#   score: 0.9867663979530334
#   label: "Right"
# }
# ]
# frame0-00-05.83.jpg      None
# frame0-00-07.20.jpg      [classification {
#   index: 1
#   score: 0.9796239137649536
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9630342721939087
#   label: "Left"
# }
# ]
# frame0-00-10.63.jpg      [classification {
#   index: 1
#   score: 0.9826935529708862
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9765782952308655
#   label: "Left"
# }
# ]
# frame0-00-01.10.jpg      None
# frame0-00-06.33.jpg      None
# frame0-00-05.63.jpg      None
# frame0-00-12.73.jpg      None
# frame0-00-12.23.jpg      None
# frame0-00-06.63.jpg      [classification {
#   index: 1
#   score: 0.9869483113288879
#   label: "Right"
# }
# ]
# frame0-00-03.33.jpg      [classification {
#   index: 1
#   score: 0.9634275436401367
#   label: "Right"
# }
# ]
# frame0-00-05.20.jpg      None
# frame0-00-10.40.jpg      [classification {
#   index: 1
#   score: 0.9759891033172607
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9785727262496948
#   label: "Left"
# }
# ]
# frame0-00-03.20.jpg      [classification {
#   index: 1
#   score: 0.9668949246406555
#   label: "Right"
# }
# ]
# frame0-00-07.63.jpg      [classification {
#   index: 0
#   score: 0.9758604168891907
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9749618172645569
#   label: "Right"
# }
# ]
# frame0-00-03.43.jpg      [classification {
#   index: 1
#   score: 0.9740065336227417
#   label: "Right"
# }
# ]
# frame0-00-08.60.jpg      [classification {
#   index: 1
#   score: 0.9395729899406433
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9726307988166809
#   label: "Left"
# }
# ]
# frame0-00-13.30.jpg      None
# frame0-00-05.13.jpg      [classification {
#   index: 0
#   score: 0.9795586466789246
#   label: "Left"
# }
# ]
# frame0-00-00.33.jpg      None
# frame0-00-04.90.jpg      [classification {
#   index: 0
#   score: 0.9657833576202393
#   label: "Left"
# }
# ]
# frame0-00-11.30.jpg      [classification {
#   index: 0
#   score: 0.9868307709693909
#   label: "Left"
# }
# ]
# frame0-00-01.50.jpg      None
# frame0-00-11.80.jpg      [classification {
#   index: 0
#   score: 0.9740233421325684
#   label: "Left"
# }
# ]
# frame0-00-05.40.jpg      [classification {
#   index: 0
#   score: 0.8055437803268433
#   label: "Left"
# }
# ]
# frame0-00-08.10.jpg      [classification {
#   index: 0
#   score: 0.9508620500564575
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9744593501091003
#   label: "Right"
# }
# ]
# frame0-00-05.70.jpg      None
# frame0-00-07.40.jpg      [classification {
#   index: 1
#   score: 0.9725167155265808
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9770880341529846
#   label: "Left"
# }
# ]
# frame0-00-04.13.jpg      None
# frame0-00-03.60.jpg      [classification {
#   index: 1
#   score: 0.9672768115997314
#   label: "Right"
# }
# ]
# frame0-00-08.30.jpg      [classification {
#   index: 1
#   score: 0.9523640275001526
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9613457322120667
#   label: "Left"
# }
# ]
# frame0-00-02.83.jpg      [classification {
#   index: 1
#   score: 0.966720461845398
#   label: "Right"
# }
# ]
# frame0-00-04.20.jpg      [classification {
#   index: 1
#   score: 0.9610788226127625
#   label: "Right"
# }
# ]
# frame0-00-09.23.jpg      [classification {
#   index: 1
#   score: 0.9681001305580139
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9761185646057129
#   label: "Left"
# }
# ]
# frame0-00-01.93.jpg      None
# frame0-00-03.10.jpg      [classification {
#   index: 1
#   score: 0.9652933478355408
#   label: "Right"
# }
# ]
# frame0-00-02.93.jpg      [classification {
#   index: 1
#   score: 0.9550890326499939
#   label: "Right"
# }
# ]
# frame0-00-00.90.jpg      None
# frame0:00:06.00.jpg      None
# frame0-00-09.40.jpg      [classification {
#   index: 1
#   score: 0.9679597020149231
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9788494110107422
#   label: "Left"
# }
# ]
# frame0-00-11.90.jpg      [classification {
#   index: 0
#   score: 0.9817721247673035
#   label: "Left"
# }
# ]
# frame0-00-11.73.jpg      [classification {
#   index: 0
#   score: 0.9675388336181641
#   label: "Left"
# }
# ]
# frame0:00:13.00.jpg      None
# frame0-00-03.93.jpg      [classification {
#   index: 1
#   score: 0.950160562992096
#   label: "Right"
# }
# ]
# frame0-00-01.23.jpg      None
# frame0-00-06.40.jpg      None
# frame0-00-10.80.jpg      [classification {
#   index: 0
#   score: 0.9800636768341064
#   label: "Left"
# }
# ]
# frame0-00-03.50.jpg      None
# frame0-00-07.50.jpg      [classification {
#   index: 1
#   score: 0.9725387096405029
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9815747737884521
#   label: "Left"
# }
# ]
# frame0-00-09.73.jpg      [classification {
#   index: 1
#   score: 0.9801512360572815
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9850360155105591
#   label: "Left"
# }
# ]
# frame0-00-12.40.jpg      None
# frame0-00-09.10.jpg      [classification {
#   index: 1
#   score: 0.9712547063827515
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9762553572654724
#   label: "Left"
# }
# ]
# frame0-00-13.50.jpg      None
# frame0-00-02.10.jpg      None
# frame0-00-03.83.jpg      [classification {
#   index: 1
#   score: 0.9481832385063171
#   label: "Right"
# }
# ]
# frame0:00:05.00.jpg      [classification {
#   index: 0
#   score: 0.9700134992599487
#   label: "Left"
# }
# ]
# frame0-00-01.43.jpg      None
# frame0-00-04.63.jpg      [classification {
#   index: 0
#   score: 0.9730890393257141
#   label: "Left"
# }
# ]
# frame0-00-13.63.jpg      None
# frame0-00-04.50.jpg      [classification {
#   index: 0
#   score: 0.9755206108093262
#   label: "Left"
# }
# ]
# frame0-00-02.60.jpg      [classification {
#   index: 1
#   score: 0.9693559408187866
#   label: "Right"
# }
# ]
# frame0-00-12.90.jpg      None
# frame0-00-12.80.jpg      None
# frame0:00:04.00.jpg      [classification {
#   index: 1
#   score: 0.9503037333488464
#   label: "Right"
# }
# ]
# frame0-00-08.73.jpg      [classification {
#   index: 1
#   score: 0.9460508823394775
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9730099439620972
#   label: "Left"
# }
# ]
# frame0-00-06.90.jpg      [classification {
#   index: 1
#   score: 0.9795034527778625
#   label: "Right"
# }
# ]
# frame0-00-00.50.jpg      None
# frame0-00-11.50.jpg      [classification {
#   index: 0
#   score: 0.9836612939834595
#   label: "Left"
# }
# ]
# frame0-00-12.30.jpg      None
# frame0-00-02.70.jpg      [classification {
#   index: 1
#   score: 0.9679122567176819
#   label: "Right"
# }
# ]
# frame0-00-11.63.jpg      [classification {
#   index: 0
#   score: 0.9841144680976868
#   label: "Left"
# }
# ]
# frame0-00-01.73.jpg      None
# frame0-00-00.73.jpg      None
# frame0-00-10.50.jpg      [classification {
#   index: 1
#   score: 0.9802582263946533
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9790819883346558
#   label: "Left"
# }
# ]
# frame0-00-05.90.jpg      None
# frame0-00-02.50.jpg      [classification {
#   index: 1
#   score: 0.9526304006576538
#   label: "Right"
# }
# ]
# frame0-00-09.80.jpg      [classification {
#   index: 1
#   score: 0.977533221244812
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9817819595336914
#   label: "Left"
# }
# ]
# frame0-00-12.50.jpg      None
# frame0-00-11.40.jpg      [classification {
#   index: 0
#   score: 0.9877774715423584
#   label: "Left"
# }
# ]
# frame0-00-08.40.jpg      [classification {
#   index: 1
#   score: 0.924375057220459
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9664463996887207
#   label: "Left"
# }
# ]
# frame0-00-01.80.jpg      None
# frame0-00-05.50.jpg      [classification {
#   index: 1
#   score: 0.9721813201904297
#   label: "Right"
# }
# ]
# frame0-00-06.83.jpg      [classification {
#   index: 1
#   score: 0.9802784323692322
#   label: "Right"
# }
# ]
# frame0-00-02.20.jpg      [classification {
#   index: 1
#   score: 0.9486189484596252
#   label: "Right"
# }
# ]
# frame0-00-11.13.jpg      [classification {
#   index: 0
#   score: 0.9735274314880371
#   label: "Left"
# }
# ]
# frame0:00:08.00.jpg      [classification {
#   index: 0
#   score: 0.9725866913795471
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.978643536567688
#   label: "Right"
# }
# ]
# frame0-00-01.30.jpg      None
# frame0:00:03.00.jpg      [classification {
#   index: 1
#   score: 0.9621856808662415
#   label: "Right"
# }
# ]
